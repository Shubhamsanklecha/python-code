# %% [markdown]
# ### Given a list of numbers, write a python program that returns a new list which Has all duplicate elements removed. And is sorted in an increasing order.
#  Ex:
# Input:
# [2,1,3,4,2,3,3,2,7,9,8,7]
# Output:
# [1,2,3,4,7,8,9]

# %%
l1=[]
a=int(input("enter the number of elements: "))
for x in range(0,a):
    v=int(input())
    l1.append(v)
l2=set(l1)
l2=list(l2)
l2.sort()
print(l2)
# Out:
# enter the number of elements: 4
# 1
# 2
# 2
# 3
# [1, 2, 3]

# %% [markdown]
# ### Write a Python program where you will iterate over both keys and values in dictionaries

# %%
dict1={"person1":"john","age":25,"height":187,"weight":75}
for x,y in dict1.items():
    print(x,y)
# Out:
# person1 john
# age 25
# height 187
# weight 75

# %% [markdown]
# ### Write a Python program that takes a dictionary of student names and returns a list of student names in alphabetical order
# Ex:
# Input:
# {“Student 1”: "Tarun", "Student 2”: "Manoj", "Student 3”: "Gephi”}
# Output:
#  [“Gephi”,”
# Manoj”,” Tarun”]

# %%
dict2={"Student 1": "Tarun", "Student 2": "Manoj", "Student 3": "Gephi"}
l2=list(dict2.values())
l2.sort()
print(l2)
# Out:
# ['Gephi', 'Manoj', 'Tarun']

# %% [markdown]
# ###  Write a Python which returns a new list of Booleans, from a given number. Iterating through the number one digit at a time, append True if the digit is 1 and False if it is 0.
# Ex:
# Input: “01001”
# Output: [“False”, “True”, “False”,” False”,” True”]

# %%
str1=input()
l1=[]
for a in str1:
    if a=="0":
        l1.append("False")
    else:
        l1.append("True")
print(l1)
# Out:
# 010101
# ['False', 'True', 'False', 'True', 'False', 'True']

# %% [markdown]
# ### Write a Python program where you will return a dictionary where the keys will be the character and the values will be the occurrence of the character in the string, and it should for any string inputs (dynamic)
# Ex:
# Input: “my name is ame”
# Output: {“m”:3,” y”:1,” n”:1,” a”:2,” e”:2,” i”:1,” s”:1}

# %%
str2=input("enter anything ")
dict2={}
for a in str2:
    dict2.update({a:str2.count(a)})
print(dict2)
# Out:
# enter anything hi how are you man
# {'h': 2, 'i': 1, ' ': 4, 'o': 2, 'w': 1, 'a': 2, 'r': 1, 'e': 1, 'y': 1, 'u': 1, 'm': 1, 'n': 1}

# %% [markdown]
# ### Given a dictionary containing the names and ages of a group of people, return the name of the oldest person
# Ex:
# Input: {"Tmma": 41, "Ackes": 45, "myna": 15, "Benthon": 29}
# Output: “Ackes”

# %%
dict3= {input():int(input()),input():int(input()),input():int(input())}
dict4=list(dict3)

print(max(dict4))
# Out:
# tmma
# 41
# myna
# 15
# benthin
# 29
# tmma

# %% [markdown]
# ###  Write a Python program to create a Rock, Paper, Scissor game, use two inputs for two players:
# ### Conditions: -Rock beats Scissors, Scissors beats Paper, Paper beats Rock

# %%
person1 = input("choose any one from stone, paper and scissor: ")
person2 = input("choose any one from stone, paper and scissor: ")
if person1 == "stone" and person2 == "scissor" or person1 == "paper" and person2 == "stone" or person1 == "scissor" and person2 == "paper":
    print("Person1 is the Winner!!!")
elif person1 == person2:
    print("its a Tie!!")
elif person1 == "scissor" and person2 == "stone" or person1 == "stone" and person2 == "paper" or person1 == "paper" and person2 == "scissor":
    print("Person2 is the Winner!!!")
else:
    print("Sorry!! Wrong input")
# Out:
# choose any one from stone, paper and scissor: stone
# choose any one from stone, paper and scissor: paper
# Person2 is the Winner!!!

# %% [markdown]
# ### . Create a program that returns a list of items that you can afford in the store with the money you have in your wallet. Create a dictionary with items as key and price as values<br>Ex:<br>Input: <br>{“water bottles”: “20”,” chips”:10,” Iphone”;49000“,” towel”:90,” pens”:58,” cake”;400}<br>Your wallet balance: -50<br>Output: [“water bottles”, “chips”]

# %%
items={"water bottles": 20,"chips":10,"Iphone":49000,"towel":90,"pens":58,"cake":400}
wallet=int(input())
l1=[] 
for y in items:
    if items[y]<=wallet:
        l1.append(y)
        wallet=wallet-items[y]
    else:
        continue
print(l1)
# Out:
# 50
# ['water bottles', 'chips']

# %% [markdown]
# ### Write a Python program to create a union of sets

# %%
print("enter the elements for 1st set")
set1={int(input()),int(input()),int(input()),int(input())}
print("enter the elements for 2nd set")
set2={int(input()),int(input()),int(input()),int(input())}
set3=set1.union(set2)
print(set3)
# Out:
# enter the elements for 1st set
# 1
# 2
# 3
# 4
# enter the elements for 2nd set
# 5
# 1
# 2
# 3
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Write a Python program to check if a given value is present in a set or not (Dynamic)

# %%
set4={"ram","shyam","1","2","3","4","@"}
x=input("enter a value: ")
if x in set4:
    print("It is present in the set!!")
else:
    print("It is not presnt in the set!!")
# Out:
# enter a value: ram
# It is present in the set!!

# %% [markdown]
# ### Write a Python program to find the occurrences of 3 most common words in a given text. And make it as a dictionaries
# <br>Ex:
# <br>Input:
# <br>” Cat dog dog cat horse dog dog mouse horse dog mouse tiger lion tiger
# <br>cat mouse snail”
# <br>Output: (“dog”:5,”cat”:3,” mouse”;3)

# %%
str1="Cat dog dog cat horse dog dog mouse horse dog mouse tiger lion tiger cat mouse snai"
str2=str1.split()
for a in str2:
    if str2.count(a)>2:

# %% [markdown]
# ### Write a Python program that accepts name of given subject and mark, and make subjects as keys in dictionaries and marks as values and print the final dictionary with subjects and marks

# %%
dict7= {input("enter 1st subject: "):int(input("enter marks for 1st subject: ")),input("enter 2nd subject: "):int(input("enter marks for 3rd subject: ")),input("enter 2nd subject: "):int(input("enter marks for 3rd subject: "))}
print(dict7)
# Out:
# enter 1st subject: English
# enter marks for 1st subject: 70
# enter 2nd subject: maths
# enter marks for 3rd subject: 65
# enter 2nd subject: hindi
# enter marks for 3rd subject: 80
# {'English': 70, 'maths': 65, 'hindi': 80}
