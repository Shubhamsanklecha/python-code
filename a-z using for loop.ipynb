# %%
for a in range(1,6):
    if a==1:
        print(" * * ")
    elif a==2:
        print("*   *")
    elif a==3:
        print("*   *")
    elif a==4:
        print(" * * **")
# Out:
#  * *
# *   *
# *   *
#  * * **

# %%
for b in range(6):
    if b==1:
        print("*")
    elif b==2:
        print("*")
    elif b==3:
        print("*****")
    elif b==4:
        print("*   *")
    elif b==5:
        print("*****")
# Out:
# *
# *
# *****
# *   *
# *****

# %%
for c in range(6):
    if c==1:
        print(" ***")
    elif c==2:
        print("*")
    elif c==3:
        print(" ***")
# Out:
#  ***
# *
#  ***

# %%
for d in range(6):
    if d==1:
        print("    *")
    elif d==2:
        print("    *")
    elif d==3:
        print("*****")
    elif d==4:
        print("*   *")
    elif d==5:                                   ee
        print("***** *")
# Out:
#     *
#     *
# *****
# *   *
# ***** *

# %%
for e in range(8):
    if e==1:
        print("  **")
    elif e==2:
        print(" *   *")
    elif e==3:
        print("******")
    elif e==4:
        print("* ")
    elif e==5:
        print(" *  *")
    elif e==6:
        print("  **")
# Out:
#   **
#  *   *
# ******
# *
#  *  *
#   **

# %%
for f in range(8):
    if f==1:
        print("   * *")
    elif f==2:
        print("  *  *")
    elif f==3:
        print("  *    ")
    elif f==4:
        print("******")
    elif f==5:
        print("  *")
    elif f==6:
        print("  *")
# Out:
#    * *
#   *  *
#   *
# ******
#   *
#   *

# %%
for g in range(8):
    if g==1:
        print(" ***")
    elif g==2:
        print("*   *   *")
    elif g==3:
        print("***** *")
    elif g==4:
        print("   **")
    elif g==5:
        print(" *  *")
    elif g==6:
        print("  * *")
# Out:
#  ***
# *   *   *
# ***** *
#    **
#  *  *
#   * *

# %%
for h in range(8):
    if h==1:
        print("*")
    elif h==2:
        print("*")
    elif h==3:
        print("****")
    elif h==4:
        print("*   *")
    elif h==5:
        print("*   *")
# Out:
# *
# *
# ****
# *   *
# *   *

# %%
for i in range(7):
    if i==1:
        print("*")
    elif i==2:
        print(" ")
    elif i==3:
        print("*")
    elif i==4:
        print("*")
    elif i==5:
        print("*")
    elif i==6:
        print("*")
# Out:
# *
#
# *
# *
# *
# *

# %%
for j in range(9):
    if j==1:
        print("   *")
    elif j==2:
        print(" ")
    elif j==3:
        print("   *")
    elif j==4:
        print("   *")
    elif j==5:
        print("*  *")
    elif j==6:
        print(" * *")
    elif j==7:
        print("   *")
# Out:
#    *
#
#    *
#    *
# *  *
#  * *
#    *

# %%
for k in range(8):
    if k==1:
        print("*  ")
    elif k==2:
        print("*  *")
    elif k==3:
        print("**")
    elif k==4:
        print("*  *")
    elif k==5:
        print("*  ")
# Out:
# *
# *  *
# **
# *  *
# *

# %%
for l in range(7):
    if l==1:
        print("*")
    elif l==2:
        print("*")
    elif l==3:
        print("*")
    elif l==4:
        print("*")
    elif l==5:
        print("*")
    elif l==6:
        print("*")
# Out:
# *
# *
# *
# *
# *
# *

# %%
for m in range(8):
    if m==1:
        print("*   *   *  ")
    elif m==2:
        print("  *   *   *")
    elif m==3:
        print("  *   *   *")
    elif m==4:
        print("  *   *   *")
# Out:
# *   *   *
#   *   *   *
#   *   *   *
#   *   *   *

# %%
for n in range(8):
    if n==1:
        print("*   *    ")
    elif n==2:
        print("  *   *   ")
    elif n==3:
        print("  *   *   ")
    elif n==4:
        print("  *   *   ")
# Out:
# *   *
#   *   *
#   *   *
#   *   *

# %%
for o in range(6):
    if o==1:
        print(" * * ")
    elif o==2:
        print("*   *")
    elif o==3:
        print("*   *")
    elif o==4:
        print(" * * ")
# Out:
#  * *
# *   *
# *   *
#  * *

# %%
for p in range(10):
    if p==1:
        print("  *  ")
    elif p==2:
        print("*   *")
    elif p==3:
        print("*    *")
    elif p==4:
        print("*   *")
    elif p==5:
        print("*  *  ")
    elif p==6:
        print("**")
    elif p==7:
        print("*")
    elif p==8:
        print("*")
    elif p==9:
        print("*")
# Out:
#   *
# *   *
# *    *
# *   *
# *  *
# **
# *
# *
# *

# %%
for r in range(8):
    if r==2:
        print("*   *  *  ")
    elif r==3:
        print("  *    *  ")
    elif r==4:
        print("  *      ")
    elif r==5:
        print("  *      ")
    elif r==1:
        print("     *")
# Out:
#      *
# *   *  *
#   *    *
#   *
#   *

# %%
for s in range(8):
    if s==1:
        print("****")
    elif s==2:
        print("*")
    elif s==3:
        print("****")
    elif s==4:
        print("   *")
    elif s==5:
        print("****")
# Out:
# ****
# *
# ****
#    *
# ****

# %%
for t in range(8):
    if t==1:
        print("  *")
    elif t==2:
        print("  *")
    elif t==3:
        print("  *")
    elif t==4:
        print("*****")
    elif t==5:
        print("  *   *")
    elif t==6:
        print("  *  *")
    elif t==7:
        print("  ***")
# Out:
#   *
#   *
#   *
# *****
#   *   *
#   *  *
#   ***

# %%
for u in range(6):
    if u==1:
        print("*  *")
    elif u==2:
        print("*  *")
    elif u==3:
        print("*  *")
    elif u==4:
        print("****")
    elif u==5:
        print("    **")
# Out:
# *  *
# *  *
# *  *
# ****
#     **

# %%
for v in range(7):
    if v==1:
        print("*        *")
    elif v==2:
        print(" *      *")
    elif v==3:
        print("   *   *")
    elif v==4:
        print("     *")
# Out:
# *        *
#  *      *
#    *   *
#      *

# %%
for w in range(6):
    if w==4:
        print("*       *")
    elif w==3:
        print("* *   * *")
    elif w==2:
        print("*   *   *")
    elif w==1:
        print("*       *")
# Out:
# *       *
# *   *   *
# * *   * *
# *       *

# %%
for x  in range(8):
    if x==1:
        print("*        *")
    elif x==2:
        print("  *    *   ")
    elif x==3:
        print("     *    ")
    elif x==4:
        print("   *    *  ")
    elif x==5:
        print(" *        *")
# Out:
# *        *
#   *    *
#      *
#    *    *
#  *        *

# %%
for y in range(9):
    if y==1:
        print(" *        *")
    elif y==2:
        print("   *    *   ")
    elif y==3:
        print("      *    ")
    elif y==4:
        print("    *      ")
    elif y==5:
        print("****        ")
    elif y==6:
        print(" *        ")
# Out:
#  *        *
#    *    *
#       *
#     *
# ****
#  *

# %%
for z in range(8):
    if z==1:
        print("*****")
    elif z==2:
        print("   *")
    elif z==3:
        print("  *")
    elif z==4:
        print(" *")
    elif z==5:
        print("*****")
# Out:
# *****
#    *
#   *
#  *
# *****
