# %%
import random as rd

# %%
print("Welcome to the game")
player1= input("enter player1 name: ")
player2= input("enter player2 name: ")
p1=0
p2=0
ladder={1:38,4:14,9:31,21:42,28:84,51:67,72:91,80:99}
snake={17:7,54:34,62:19,64:60,87:36,93:73,95:75,98:79}
def game(pos):
    dice=rd.randint(1,6)
    pos+=dice
    print("dice face is: ",dice)
    if dice==6:
        dice=rd.randint(1,6)
        pos+=dice
        print("dice face is: ",dice)
        print("{} is your current position ".format(pos))
    elif pos>100:
        print("Not possible!!!")
        pos-=dice
        dice=rd.randint(1,6)
        pos+=dice
    elif pos in snake:
        pos=snake[pos]
        print("snake caught you!!, your new position is {}".format(pos))
        print(pos)
    elif pos in ladder:
        pos=ladder[pos]
        print("you got a ladder!!, your new position is {}".format(pos))
        print(pos)
    else:
        print("{} is your current position ".format(pos))
    return pos
        
while True:
    input("{} press enter to move: ".format(player1))
    p1=game(p1)
    if p1>=100:
        print("{} is the winnerrr!!!".format(player1))
        break
    input("{} press enter to move: ".format(player2))
    p2=game(p2)
    if p2>=100:
        print("{} is the winnerrr!!!".format(player2))
        break
# Out:
# Welcome to the game
# enter player1 name: a
# enter player2 name: b
# a press enter to move:
# dice face is:  6
# dice face is:  5
# 11 is your current position
# b press enter to move:
# dice face is:  1
# you got a ladder!!, your new position is 38
# 38
# a press enter to move:
# dice face is:  4
# 15 is your current position
# b press enter to move:
# dice face is:  2
# 40 is your current position
# a press enter to move:
# dice face is:  1
# 16 is your current position
# b press enter to move:
# dice face is:  1
# 41 is your current position
# a press enter to move:
# dice face is:  1
# snake caught you!!, your new position is 7
# 7
# b press enter to move:
# dice face is:  4
# 45 is your current position
# a press enter to move:
# dice face is:  3
# 10 is your current position
# b press enter to move:
# dice face is:  6
# dice face is:  2
# 53 is your current position
# a press enter to move:
# dice face is:  3
# 13 is your current position
# b press enter to move:
# dice face is:  1
# snake caught you!!, your new position is 34
# 34
# a press enter to move:
# dice face is:  3
# 16 is your current position
# b press enter to move:
# dice face is:  6
# dice face is:  1
# 41 is your current position
# a press enter to move:
# dice face is:  4
# 20 is your current position
# b press enter to move:
# dice face is:  1
# 42 is your current position
# a press enter to move:
# dice face is:  5
# 25 is your current position
# b press enter to move:
# dice face is:  5
# 47 is your current position
# a press enter to move:
# dice face is:  5
# 30 is your current position
# b press enter to move:
# dice face is:  3
# 50 is your current position
# a press enter to move:
# dice face is:  5
# 35 is your current position
# b press enter to move:
# dice face is:  2
# 52 is your current position
# a press enter to move:
# dice face is:  2
# 37 is your current position
# b press enter to move:
# dice face is:  2
# snake caught you!!, your new position is 34
# 34
# a press enter to move:
# dice face is:  5
# 42 is your current position
# b press enter to move:
# dice face is:  2
# 36 is your current position
# a press enter to move:
# dice face is:  2
# 44 is your current position
# b press enter to move:
# dice face is:  2
# 38 is your current position
# a press enter to move:
# dice face is:  6
# dice face is:  5
# 55 is your current position
# b press enter to move:
# dice face is:  2
# 40 is your current position
# a press enter to move:
# dice face is:  1
# 56 is your current position
# b press enter to move:
# dice face is:  4
# 44 is your current position
# a press enter to move:
# dice face is:  6
# dice face is:  2
# 64 is your current position
# b press enter to move:
# dice face is:  2
# 46 is your current position
# a press enter to move:
# dice face is:  3
# 67 is your current position
# b press enter to move:
# dice face is:  2
# 48 is your current position
# a press enter to move:
# dice face is:  5
# you got a ladder!!, your new position is 91
# 91
# b press enter to move:
# dice face is:  1
# 49 is your current position
# a press enter to move:
# dice face is:  1
# 92 is your current position
# b press enter to move:
# dice face is:  3
# 52 is your current position
# a press enter to move:
# dice face is:  2
# 94 is your current position
# b press enter to move:
# dice face is:  5
# 57 is your current position
# a press enter to move:
# dice face is:  4
# snake caught you!!, your new position is 79
# 79
# b press enter to move:
# dice face is:  5
# snake caught you!!, your new position is 19
# 19
# a press enter to move:
# dice face is:  5
# 84 is your current position
# b press enter to move:
# dice face is:  6
# dice face is:  5
# 30 is your current position
# a press enter to move:
# dice face is:  3
# snake caught you!!, your new position is 36
# 36
# b press enter to move:
# dice face is:  6
# dice face is:  2
# 38 is your current position
# a press enter to move:
# dice face is:  6
# dice face is:  5
# 47 is your current position
# b press enter to move:
# dice face is:  3
# 41 is your current position
# a press enter to move:
# dice face is:  4
# you got a ladder!!, your new position is 67
# 67
# b press enter to move:
# dice face is:  6
# dice face is:  3
# 50 is your current position
# a press enter to move:
# dice face is:  4
# 71 is your current position
# b press enter to move:
# dice face is:  4
# snake caught you!!, your new position is 34
# 34
# a press enter to move:
# dice face is:  4
# 75 is your current position
# b press enter to move:
# dice face is:  4
# 38 is your current position
# a press enter to move:
# dice face is:  3
# 78 is your current position
# b press enter to move:
# dice face is:  3
# 41 is your current position
# a press enter to move:
# dice face is:  2
# you got a ladder!!, your new position is 99
# 99
# b press enter to move:
# dice face is:  3
# 44 is your current position
# a press enter to move:
# dice face is:  5
# Not possible!!!
# a is the winnerrr!!!

# %%
dice=rd.randint(1,6)

# %%
dice
# Out:
# 6

# %%
dice
# Out:
# 6

# %%
dice=rd.randint(1,6)

# %%
dice
# Out:
# 5
